# %% [markdown]
# # Data Extraction Form - Research Question 6 (RQ6)
# ## What metrics are used to evaluate the VM consolidation solutions?
#
# This notebook analyses the collected data to answer the RQ6.

# %%
from utils import *

# %%
metrics_df = DataExtraction().get_metrics()

# %%
total_papers = len(metrics_df)
metrics = (metrics_df.str.split(',')
                     .explode()
                     .str.strip()
                     .value_counts())

metrics = (metrics.reset_index()
                  .rename(columns={Table.INDEX: DataExtraction.METRICS, DataExtraction.METRICS: Table.AMOUNT}))

for index, columns in metrics.iterrows():
    print(f'{columns[0]:<70} {columns[1]:>2}')
# Out:
# Energy Consumption                                                     63
# Number of VM Migrations                                                51
# SLA Violation (SLAV)                                                   42
# SLA Violation Time per Active Host (SLATAH)                            42
# Performance Degradation due to Migration (PDM)                         42
# Energy-SLA Violation (ESV)                                             19
# Number of PM Shutdowns                                                 16
# Number of Active PMs                                                   12
# Execution Time                                                          9
# Overall SLA Violation                                                   8
# Resource Utilization                                                    6
# Average SLA Violation                                                   5
# Energy Efficiency                                                       3
# Number of Hot Spots                                                     3
# Completion Time                                                         3
# Makespan                                                                3
# Number of SLA Violations                                                3
# Resource Wastage                                                        3
# Number of Cold Spots                                                    2
# Prediction Accuracy                                                     2
# Energy-SLAV-Migration                                                   2
# Hypervolume                                                             2
# CPU Thermal SLA                                                         2
# Computational Energy                                                    2
# Data Transfer                                                           2
# Inverted Generational Distance                                          2
# Load Balancing                                                          2
# Mean Time Before PM Shutdown                                            2
# Migration Energy Consumption                                            1
# Active PM Time                                                          1
# Number of Sleeping PMs                                                  1
# Time Overloaded                                                         1
# Number of Active Modules                                                1
# QoS violation (%)                                                       1
# First Rank Occurrence                                                   1
# Overall Cost                                                            1
# Costs of Energy and Switching and SLA Violation (CESSV)                 1
# Number of Re-Overloaded PMs                                             1
# Power consumption and SLAV ans number of VM migrations count (PSM)      1
# Average PUE (kWh)                                                       1
# Spread                                                                  1
# Number of PM Reactivations                                              1
# Balance Factor                                                          1
# Average Percentage Increase in Execution time (APIE)                    1
# Multi Parameter SLA Violation (MPSV)                                    1
# Relative Score to Best One                                              1
# Switch Energy Consumption                                               1
# Communication Cost Energy Consumption                                   1
# Performance Metric (Pertric)                                            1
# Number of Power State Changes                                           1
# Memory Demand Violations (MDV)                                          1
# Performance Ratio Metric (PRM)                                          1
# Greenhouse Gas Emissions                                                1
# Bandwidth Demand Violations (BDV)                                       1
# Average Traffic Gain                                                    1
# Number of Active Cores                                                  1
# Generational Distance                                                   1
# Deadlines Missed                                                        1
# Average Rank                                                            1
# Response Time                                                           1
# Epsilon (EPS)                                                           1
# Number of Active Racks                                                  1
# Network Power Consumption                                               1
# CPU Temperature                                                         1
# Latency                                                                 1
# Mean Time Before VM Migration                                           1
# Minimization of energy SLA violation and number of VMs migrations (ESM)  1
# Average Power (kW)                                                      1

# %%
plot_horizontal_bar_chart(metrics.head(10), 
                          x=DataExtraction.AMOUNT, 
                          y=DataExtraction.METRICS, 
                          xlim=(0, 100), 
                          total=total_papers, 
                          filename='RQ6-Metrics.pdf')
